# %% [markdown]
# <a href="https://colab.research.google.com/github/shyambista123/Machine-Learning/blob/main/learning_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ### DataFrame

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'],
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %% [markdown]
# ### Series

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %% [markdown]
# ### Reading data files

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# reading just a sample data
read_csv_data = pd.read_csv('/content/drive/MyDrive/train.csv')

# %%
read_csv_data.shape
# Out:
# (1460, 81)

# %%
read_csv_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# read_csv_data = pd.read_csv('/content/drive/MyDrive/train.csv', index_col=0)
read_csv_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ### Native accessors

# %%
read_csv_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
read_csv_data.Condition1
# Out:
# 0        Norm
# 1       Feedr
# 2        Norm
# 3        Norm
# 4        Norm
#         ...
# 1455     Norm
# 1456     Norm
# 1457     Norm
# 1458     Norm
# 1459     Norm
# Name: Condition1, Length: 1460, dtype: object

# %%
read_csv_data['Condition1']
# Out:
# 0        Norm
# 1       Feedr
# 2        Norm
# 3        Norm
# 4        Norm
#         ...
# 1455     Norm
# 1456     Norm
# 1457     Norm
# 1458     Norm
# 1459     Norm
# Name: Condition1, Length: 1460, dtype: object

# %%
read_csv_data['Condition1'][0]
# Out:
# 'Norm'

# %% [markdown]
# ### Indexing in pandas

# %%
read_csv_data.iloc[0]
# Out:
# Id                    1
# MSSubClass           60
# MSZoning             RL
# LotFrontage        65.0
# LotArea            8450
#                   ...
# MoSold                2
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        208500
# Name: 0, Length: 81, dtype: object

# %%
read_csv_data.iloc[:, 0]
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1455    1456
# 1456    1457
# 1457    1458
# 1458    1459
# 1459    1460
# Name: Id, Length: 1460, dtype: int64

# %%
read_csv_data.iloc[:3, 0]
# Out:
# 0    1
# 1    2
# 2    3
# Name: Id, dtype: int64

# %%
read_csv_data.iloc[-5]
# Out:
# Id                 1456
# MSSubClass           60
# MSZoning             RL
# LotFrontage        62.0
# LotArea            7917
#                   ...
# MoSold                8
# YrSold             2007
# SaleType             WD
# SaleCondition    Normal
# SalePrice        175000
# Name: 1455, Length: 81, dtype: object

# %%
read_csv_data.loc[read_csv_data.MSSubClass.notnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ### Grouping and Sorting

# %%
read_csv_data.groupby('MSSubClass').MSSubClass.count()
# Out:
# MSSubClass
# 20     536
# 30      69
# 40       4
# 45      12
# 50     144
# 60     299
# 70      60
# 75      16
# 80      58
# 85      20
# 90      52
# 120     87
# 160     63
# 180     10
# 190     30
# Name: SalePrice, dtype: int64

# %%
read_csv_data.groupby('MSSubClass').SalePrice.min()
# Out:
# MSSubClass
# 20      35311
# 30      34900
# 40      79500
# 45      76000
# 50      37900
# 60     129000
# 70      40000
# 75     101000
# 80     107000
# 85     123000
# 90      82000
# 120     99500
# 160     75000
# 180     75500
# 190     55000
# Name: SalePrice, dtype: int64

# %%
read_csv_data.groupby('MSSubClass').SalePrice.max()
# Out:
# MSSubClass
# 20     611657
# 30     163500
# 40     260000
# 45     139400
# 50     410000
# 60     755000
# 70     359100
# 75     475000
# 80     345000
# 85     198500
# 90     206300
# 120    392500
# 160    239000
# 180    148000
# 190    228950
# Name: SalePrice, dtype: int64
